# %%
# Huzefa Ansari | BMEN 415 | Final Project | Classification Models | MLP Classifier


# Immport Models

import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Download Files and Curate Data

dataFile = pd.read_csv ('water_potability.csv')

dataFile = dataFile.dropna()

x = dataFile.drop(columns = ['Potability']).copy()
y = dataFile ['Potability']

# Test/Train Split

x_train, x_test, y_train, y_test = train_test_split (x,y,test_size = 0.2, random_state = 42)

# %%
# Correlation Matrix

waterpot_hm = sns.heatmap(dataFile.corr(), annot = False)

# %%
# Import Class

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# Fit Model and Predict

QDA_Model = QuadraticDiscriminantAnalysis ()
QDA_Model.fit (x_train,y_train)
QDA_Prediction = QDA_Model.predict (x_test)
QDA_TrainPrediction = QDA_Model.predict (x_train)

# Metrics

from sklearn import metrics
print ("The Accuracy for the Test Model is:", metrics.accuracy_score(y_test,QDA_Prediction))
print ("The Accuracy for the Train Model is:", metrics.accuracy_score(y_train,QDA_TrainPrediction))

# Confusion Matrix

conf_mat = confusion_matrix(y_test, QDA_Prediction)
heatmap = sns.heatmap(conf_mat, annot=True, fmt='.0f')
sns.set(font_scale=1.2)
sns.set_style({'font.family':'serif', 'font.serif':'Times New Roman'})
sns.set(rc={'figure.figsize':(6,6)})
sns.set_palette("pastel")
plt.title('Correlation Matrix Heatmap')
heatmap.set_xlabel('Predicted')
heatmap.set_ylabel('True Values')
# Out:
# The Accuracy for the Test Model is: 0.4267990074441687
# The Accuracy for the Train Model is: 0.39800995024875624
# Text(33.0, 0.5, 'True Values')
